# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="20%">
#             <img src="GL-2.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b> Take-Home <br>(Day 4)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### About the dataset (Life Expectancy Data)
#
# The dataset contains the health data of 2938 individuals useful for predicting the life expentency of the individuals. The features are related to economical factors, immunity realted factors, social factors and so on.
#
# Attribute Information:
#
# **Country:** Country of the recorded data
#
# **Year:** Year of the recorded data
#
# **Status:** Status of the country
#
# **Life expectancy:** Life expectancy in age (target/dependent variable)
#
# **Adult mortality:** Rate of adult mortality
#
# **Infant deaths:** Number of Infant Deaths per 1000 population
#
# **Alcohol:** Alcohol consumption (in litres of pure alcohol)
#
# **Percentage expenditure:** Expenditure on health as a percentage of GDP
#
# **Hepatitis B:** Hepatitis B immunization coverage among 1-year-olds (%)
#
# **Measles:** Number of reported cases per 1000 population
#
# **BMI:** Average BMI of entire population
#
# **Under-five deaths:** Number of under-five deaths per 1000 population
#
# **Polio:** Polio immunization coverage among 1-year-olds (%)
#
# **Total expenditure:** Government expenditure on health as a percentage of total government expenditure (%)
#
# **Diphtheria:** DTP3 immunization coverage among 1-year-olds (%)
#
# **HIV/AIDS:** Deaths per 1000 live births HIV/AIDS (0-4 years)
#
# **GDP:** Gross Domestic Product per capita (in USD)
#
# **Population:** Population of the country
#
# **Thinness 1-19 years:** Prevalence of thinness for age 1 to 19 (%)
#
# **Thinness 5-9 years:** Prevalence of thinness for age 5 to 9 (%)
#
# **Income composition of resources:** Human Development Index in terms of income composition of resources
#
# **Schooling:** Number of years of Schooling

# %% [markdown]
# **Import the required libraries**

# %%
# Import the Libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# Visualizing Charts.
plt.rcParams['figure.figsize']=[15,6]

from IPython.display import display, HTML                                             ## Increasing width of notebook.
display(HTML("<style>.container { width:95% !important; }</style>"))
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.model_selection import train_test_split as tts
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# #### Load the life expectancy dataset and print the first five observations

# %%
life = pd.read_csv('Life Expectancy Data.csv')
life.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0    6.0               8.16        65.0       0.1  584.259210    33736494
# 1   58.0               8.18        62.0       0.1  612.696514      327582
# 2   62.0               8.13        64.0       0.1  631.744976    31731688
# 3   67.0               8.52        67.0       0.1  669.959000     3696958
# 4   68.0               7.87        68.0       0.1   63.537231     2978599
#
#    Thinness  1-19 years Thinness 5-9 years  Income composition of resources  \
# 0                  17.2               17.3                            0.479
# 1                  17.5               17.5                            0.476
# 2                  17.7               17.7                            0.470
# 3                  17.9               18.0                            0.463
# 4                  18.2               18.2                            0.454
#
#    Schooling
# 0       10.1
# 1       10.0
# 2        9.9
# 3        9.8
# 4        9.5
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Check the data type of each variable and if any variable is wrongly identified, do the needful</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
life['Population'] = pd.to_numeric(life['Population'],errors='coerce')

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Create a DataFrame containing the count and percentage of missing entries in each variable</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
x=df.isnull().sum()/life.shape[0]
dataframe = pd.DataFrame(x,columns=['percentage'])
dataframe['count'] = life.isnull().sum()
dataframe
# Out:
#                                  percentage  count
# Country                            0.000000      0
# Year                               0.000000      0
# Status                             0.005446     16
# Life expectancy                    0.003404     10
# Adult mortality                    0.003404     10
# Infant deaths                      0.000000      0
# Alcohol                            0.066031    194
# Percentage expenditure             0.000000      0
# Hepatitis B                        0.188223    553
# Measles                            0.000000      0
# BMI                                0.011572     34
# Under-five deaths                  0.000000      0
# Polio                              0.006467     19
# Total expenditure                  0.076923    226
# Diphtheria                         0.006467     19
# HIV/AIDS                           0.000000      0
# GDP                                0.152485    448
# Population                         0.000000    652
# Thinness  1-19 years               0.011572     34
# Thinness 5-9 years                 0.011572     34
# Income composition of resources    0.056841    167
# Schooling                          0.055480    163

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3a. Are there any extreme values present in the government's total expenditure on health?
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
life['Total expenditure'].describe()
# Out:
# count    2712.00000
# mean        5.93819
# std         2.49832
# min         0.37000
# 25%         4.26000
# 50%         5.75500
# 75%         7.49250
# max        17.60000
# Name: Total expenditure, dtype: float64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3b. Remove the outliers present in 'Total expenditure' using the quartiles of the variable
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
q1=life['Total expenditure'].quantile(0.25)
q3=life['Total expenditure'].quantile(0.75)
iqr=q3-q1

upper=q3+1.5*iqr

lower=q1-1.5*iqr

df = life.loc[~((life['Total expenditure']>upper) | (life['Total expenditure']<lower)),:]
df.describe()
# Out:
#               Year  Life expectancy  Adult mortality  Infant deaths  \
# count  2906.000000      2898.000000      2898.000000    2906.000000
# mean   2007.505850        69.205383       165.088682      30.466965
# std       4.617277         9.519585       124.309465     118.555946
# min    2000.000000        36.300000         1.000000       0.000000
# 25%    2003.250000        63.025000        74.000000       0.000000
# 50%    2007.000000        72.100000       144.000000       3.000000
# 75%    2012.000000        75.600000       228.000000      21.000000
# max    2015.000000        89.000000       723.000000    1800.000000
#
#            Alcohol  Percentage expenditure  Hepatitis B        Measles  \
# count  2712.000000             2906.000000  2354.000000    2906.000000
# mean      4.593857              745.228181    80.966440    2444.286648
# std       4.057365             1997.312698    25.031662   11527.644280
# min       0.010000                0.000000     1.000000       0.000000
# 25%       0.867500                5.385679    77.000000       0.000000
# 50%       3.725000               67.655779    92.000000      16.000000
# 75%       7.642500              447.501609    97.000000     372.000000
# max      17.870000            19479.911610    99.000000  212183.000000
#
#                BMI  Under-five deaths        Polio  Total expenditure  \
# count  2872.000000        2906.000000  2887.000000        2680.000000
# mean     38.145543          42.286304    82.576377           5.832951
# std      19.937503         161.299335    23.411864           2.312034
# min       1.000000           0.000000     3.000000           0.370000
# 25%      19.275000           0.000000    78.000000           4.250000
# 50%      43.150000           4.000000    93.000000           5.710000
# 75%      56.000000          26.750000    97.000000           7.430000
# max      87.300000        2500.000000    99.000000          12.250000
#
#         Diphtheria     HIV/AIDS            GDP    Population  \
# count  2887.000000  2906.000000    2482.000000  2.279000e+03
# mean     82.304468     1.755747    7500.358071  1.278873e+07
# std      23.735574     5.101646   14289.223670  6.110234e+07
# min       2.000000     0.100000       1.681350  3.400000e+01
# 25%      78.000000     0.100000     464.452290  1.978615e+05
# 50%      93.000000     0.100000    1770.253970  1.395398e+06
# 75%      97.000000     0.800000    5929.224503  7.440779e+06
# max      99.000000    50.600000  119172.741800  1.293859e+09
#
#        Thinness  1-19 years  Thinness 5-9 years  \
# count           2872.000000         2872.000000
# mean               4.874095            4.905675
# std                4.421397            4.510241
# min                0.100000            0.100000
# 25%                1.600000            1.600000
# 50%                3.400000            3.400000
# 75%                7.200000            7.200000
# max               27.700000           28.600000
#
#        Income composition of resources    Schooling
# count                      2758.000000  2760.000000
# mean                          0.627885    12.006884
# std                           0.211172     3.349832
# min                           0.000000     0.000000
# 25%                           0.493000    10.100000
# 50%                           0.678000    12.400000
# 75%                           0.780000    14.300000
# max                           0.948000    20.700000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4. Split the data such that 'X' will contain all the indepentdent variables and 'y' will contain the target variable</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Hint:** 'Life expectancy' is the target variable depending on the remaining variables.

# %%
X = df.drop('Life expectancy',axis=1)
y = df['Life expectancy']

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Split the independent variables into two sets with the proportion of 70:30</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
from sklearn.model_selection import train_test_split as tts

xtrain,xtest,ytrain,ytest=tts(X,y,random_state=0,test_size=0.3)
print(xtrain.shape,xtest.shape,ytrain.shape,ytest.shape)
# Out:
# (2034, 21) (872, 21) (2034,) (872,)

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. How would you treat the missing values in the variable 'GDP'?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
life['GDP'].describe()
# Out:
# count      2490.000000
# mean       7483.158469
# std       14270.169342
# min           1.681350
# 25%         463.935626
# 50%        1766.947595
# 75%        5910.806335
# max      119172.741800
# Name: GDP, dtype: float64

# %%
life.loc[life['GDP'].isnull(),'GDP'] = life['GDP'].median()
life.loc[life['GDP'].isnull(),'GDP']
# Out:
# Series([], Name: GDP, dtype: float64)

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7.There are 16 observations for which the status of the corresponding country is unknown, impute this status with an appropriate values</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
life.groupby('Country')['Status'].unique()
# Out:
# Country
# Afghanistan                           [Developing, nan]
# Albania                               [Developing, nan]
# Algeria                               [Developing, nan]
# Angola                                     [Developing]
# Antigua and Barbuda                   [Developing, nan]
#                                             ...
# Venezuela (Bolivarian Republic of)         [Developing]
# Viet Nam                                   [Developing]
# Yemen                                      [Developing]
# Zambia                                     [Developing]
# Zimbabwe                                   [Developing]
# Name: Status, Length: 193, dtype: object

# %%
life['Status']=life.groupby('Country')['Status'].transform(lambda x:x.fillna(x.mode()))

# %%
life
# Out:
#           Country  Year      Status  Life expectancy  Adult mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# 0                62     0.01               71.279624         65.0     1154
# 1                64     0.01               73.523582         62.0      492
# 2                66     0.01               73.219243         64.0      430
# 3                69     0.01               78.184215         67.0     2787
# 4                71     0.01                7.097109         68.0     3013
# ...             ...      ...                     ...          ...      ...
# 2933             27     4.36                0.000000         68.0       31
# 2934             26     4.06                0.000000          7.0      998
# 2935             25     4.43                0.000000         73.0      304
# 2936             25     1.72                0.000000         76.0      529
# 2937             24     1.68                0.000000         79.0     1483
#
#       ...  Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  \
# 0     ...    6.0               8.16        65.0       0.1  584.259210
# 1     ...   58.0               8.18        62.0       0.1  612.696514
# 2     ...   62.0               8.13        64.0       0.1  631.744976
# 3     ...   67.0               8.52        67.0       0.1  669.959000
# 4     ...   68.0               7.87        68.0       0.1   63.537231
# ...   ...    ...                ...         ...       ...         ...
# 2933  ...   67.0               7.13        65.0      33.6  454.366654
# 2934  ...    7.0               6.52        68.0      36.7  453.351155
# 2935  ...   73.0               6.53        71.0      39.8   57.348340
# 2936  ...   76.0               6.16        75.0      42.1  548.587312
# 2937  ...   78.0               7.10        78.0      43.5  547.358878
#
#       Population  Thinness  1-19 years  Thinness 5-9 years  \
# 0     33736494.0                  17.2                17.3
# 1       327582.0                  17.5                17.5
# 2     31731688.0                  17.7                17.7
# 3      3696958.0                  17.9                18.0
# 4      2978599.0                  18.2                18.2
# ...          ...                   ...                 ...
# 2933  12777511.0                   9.4                 9.4
# 2934  12633897.0                   9.8                 9.9
# 2935    125525.0                   1.2                 1.3
# 2936  12366165.0                   1.6                 1.7
# 2937  12222251.0                  11.0                11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [2938 rows x 22 columns]

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Define a function to find the extreme values in alcohol consumption
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
def outlier_detector(x):
    q1=x.quantile(0.25)
    q3=x.quantile(0.75)
    iqr=q3-q1
    ul=q3+1.5*iqr
    
    ll=q1-1.5*iqr
    return ul,ll
    
outlier_detector(df['Alcohol'])
# Out:
# (17.805, -9.295000000000002)

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Create a column 'Life_expectancy_level' such that it will contain three levels (High, Medium, Low) based on the life expectancy </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
life['Life expectancy'].quantile(0.25)
# Out:
# 63.1

# %%
# type your code here
def categ(x):
    if x <54.0 and x>0.0:
        return 'Low'
    elif x >=54.0 and x<72:
        return 'Medium'
    else:
        return 'High'
life['Life expectancy'].describe()
life['Life_expectancy_level']=life['Life expectancy'].apply(categ)
life
# Out:
#           Country  Year      Status  Life expectancy  Adult mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# 0                62     0.01               71.279624         65.0     1154
# 1                64     0.01               73.523582         62.0      492
# 2                66     0.01               73.219243         64.0      430
# 3                69     0.01               78.184215         67.0     2787
# 4                71     0.01                7.097109         68.0     3013
# ...             ...      ...                     ...          ...      ...
# 2933             27     4.36                0.000000         68.0       31
# 2934             26     4.06                0.000000          7.0      998
# 2935             25     4.43                0.000000         73.0      304
# 2936             25     1.72                0.000000         76.0      529
# 2937             24     1.68                0.000000         79.0     1483
#
#       ...  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0     ...               8.16        65.0       0.1  584.259210  33736494.0
# 1     ...               8.18        62.0       0.1  612.696514    327582.0
# 2     ...               8.13        64.0       0.1  631.744976  31731688.0
# 3     ...               8.52        67.0       0.1  669.959000   3696958.0
# 4     ...               7.87        68.0       0.1   63.537231   2978599.0
# ...   ...                ...         ...       ...         ...         ...
# 2933  ...               7.13        65.0      33.6  454.366654  12777511.0
# 2934  ...               6.52        68.0      36.7  453.351155  12633897.0
# 2935  ...               6.53        71.0      39.8   57.348340    125525.0
# 2936  ...               6.16        75.0      42.1  548.587312  12366165.0
# 2937  ...               7.10        78.0      43.5  547.358878  12222251.0
#
#       Thinness  1-19 years  Thinness 5-9 years  \
# 0                     17.2                17.3
# 1                     17.5                17.5
# 2                     17.7                17.7
# 3                     17.9                18.0
# 4                     18.2                18.2
# ...                    ...                 ...
# 2933                   9.4                 9.4
# 2934                   9.8                 9.9
# 2935                   1.2                 1.3
# 2936                   1.6                 1.7
# 2937                  11.0                11.2
#
#       Income composition of resources  Schooling  Life_expectancy_level
# 0                               0.479       10.1                 Medium
# 1                               0.476       10.0                 Medium
# 2                               0.470        9.9                 Medium
# 3                               0.463        9.8                 Medium
# 4                               0.454        9.5                 Medium
# ...                               ...        ...                    ...
# 2933                            0.407        9.2                    Low
# 2934                            0.418        9.5                    Low
# 2935                            0.427       10.0                    Low
# 2936                            0.427        9.8                    Low
# 2937                            0.434        9.8                    Low
#
# [2938 rows x 23 columns]

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Check how life expectancy has changed over the years in China</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
dff = life.loc[life['Country']=='China',['Life expectancy','Year']]
sns.scatterplot(x=dff['Life expectancy'],y=dff['Year'])
plt.show()

#we can see a trend clearly that the life expectancy in china is increasing over the years
