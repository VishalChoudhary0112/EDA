# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="20%">
#             <img src="GL-2.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b> Inclass - Lab <br>(Day 2)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### About the dataset (Health Insurance Data)
#
# The dataset contains information about 1300 individuals regarding insurance charges. The data contains an individual's basic information like age, sex, bmi, the region of residence and so on.
#
# Attribute Information:
#
# **age**: Age of the individual
#
# **gender**: Gender of the individual
#
# **bmi**: Body mass index of the individual
#
# **bp**: Systolic blood pressure in mm/hg
#
# **children**: Number of children of the individual
#
# **smoker**: Individual is smoker or not
#
# **region**: Individual's region of residence
#
# **medical_cost**: Individual's medical costs billed by the insurance company

# %% [markdown]
# ##  Table of Content
#
# 1. **[Univariate Analysis](#uni)**
# 2. **[Multivariate Analysis](#multi)**
# 3. **[Handle Non-Numeric Data](#cat)**
# 4. **[Normalization](#norm)**
# 5. **[Transformation Techniques](#trans)**

# %% [markdown]
# **Import the required libraries**

# %%
# import your code here
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize']=[15,6]
from sklearn.preprocessing import StandardScaler, MinMaxScaler
sc=StandardScaler()
mm = MinMaxScaler()

# %%
health=pd.read_csv('health_insurance.csv')
health.head(5)
# Out:
#    age gender     bmi  bp   children     region      smoker  medical_cost
# 0   23      M  31.900  157         0  southwest      smoker   16884.92400
# 1   20      F  36.770  160         1  southeast  non-smoker    1725.55230
# 2   33      F  35.000  145         3  southeast  non-smoker    4449.46200
# 3   37      F  23.705  153         0  northwest  non-smoker   21984.47061
# 4   36      F  27.880  156         0  northwest  non-smoker    3866.85520

# %% [markdown]
# #### Load the health insurance dataset and check the first five observations

# %%
# import your code here

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id="uni"> </a>
# ## 1. Univariate Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Are there any extreme observations present in 'bmi'? Support your answer with a plot
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
sns.boxplot(health['bmi'])
# Out:
# C:\Users\acer\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bmi'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Is the variable 'age' skewed? Support your answer with a plot and metric</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
sns.distplot(health['age'])
health.age.skew()
# Out:
# C:\Users\acer\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 0.04359793424360781

# %%
health.age.kurt()
# Out:
# -1.2267472779310922

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. What is the probability that the individuals have charged less than 25k for medical treatment? Support your answer with the plot</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
favoc=health.loc[health.medical_cost<25000].shape[0]
total=health.shape[0]

prob=favoc/total
print('Probability=',prob)
# Out:
# Probability= 0.8523076923076923

# %%
sns.distplot(health['medical_cost'])
plt.axvline(25000,color='hotpink')
# Out:
# C:\Users\acer\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4. Draw the line for mean and median on the distribution plot and identify the type of skewness for BMI</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
sns.distplot(health['bmi'])
print(health['bmi'].skew())
plt.axvline(health['bmi'].mean(),color='red')
plt.axvline(health['bmi'].median(),color='black')
#skewness is normally distributed
# Out:
# 0.2496769760401315
# C:\Users\acer\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
health['bmi'].kurt()
# Out:
# 0.16156780310996366

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Visualize the distribution of medical cost using violin plot and describe its distribution</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
sns.violinplot(health['medical_cost'])
health['medical_cost'].describe()
# Out:
# C:\Users\acer\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# count     1300.000000
# mean     13243.214691
# std      12060.371167
# min       1121.873900
# 25%       4760.155950
# 50%       9388.753650
# 75%      16579.959053
# max      63770.428010
# Name: medical_cost, dtype: float64

# %% [markdown]
# <a id="multi"> </a>
# ## 2. Multivariate Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. Is there any individual with age less than 30 and meadical cost greater than 40k?
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
health.loc[(health['age']<30)&(health.medical_cost>40000)]
# Out:
#       age gender    bmi  bp   children     region  smoker  medical_cost
# 254    26      F  47.54  156         2  northeast  smoker    42112.2356
# 1009   25      F  55.58  152         1  northeast  smoker    44501.3982
# 1086   26      M  41.75  152         1  northeast  smoker    40904.1995

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. Does the scatter plot of BMI and medical cost reveal potential outliers?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
sns.scatterplot(x=health['bmi'],y=health['medical_cost'],hue=health.smoker)
plt.legend()

#yes we can see outliers

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Determine the percentage variation in BMI for males and females
#
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
a=health.groupby('gender')['bmi'].std()
b=health.groupby('gender')['bmi'].mean()
c=a/b
c
# Out:
# gender
# F    0.201200
# M    0.201183
# Name: bmi, dtype: float64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Which region has the highest number of males?
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
health.groupby('gender')['region'].value_counts()
# Out:
# gender  region
# F       southeast    178
#         northeast    174
#         southwest    156
#         northwest    149
# M       southeast    178
#         northwest    166
#         southwest    158
#         northeast    141
# Name: region, dtype: int64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Analyze the pairwise relationship between the numeric variables
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
sns.pairplot(health,hue='gender')

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>11. Are the medical costs affected by an individual's smoking habits?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
sns.boxplot(x='smoker',y='medical_cost',data=health)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='medical_cost'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>12. Check if the region of residence and age of the individuals have an impact on the medical cost? </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
sns.scatterplot(x=health['age'],y=health['medical_cost'],hue=health['region'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='medical_cost'>

# %% [markdown]
# <a id="cat"> </a>
# ## 3. Handle Non-Numeric Data

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>13. Create a dummy variable for each category in 'region'
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
pd.get_dummies(health.region,drop_first=True)
# Out:
#       northwest  southeast  southwest
# 0             0          0          1
# 1             0          1          0
# 2             0          1          0
# 3             1          0          0
# 4             1          0          0
# ...         ...        ...        ...
# 1295          0          0          1
# 1296          0          0          0
# 1297          0          1          0
# 1298          1          0          0
# 1299          1          0          0
#
# [1300 rows x 3 columns]

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>14. Create a variable 'smoker_label' containing unique label for each category in the variable 'smoker'
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
def labeler(x):
    if x=='smoker':
        return 1
    else:
        return 0
health['smoker_label']=health['smoker'].apply(labeler)
health
# Out:
#       age gender     bmi  bp   children     region      smoker  medical_cost  \
# 0      23      M  31.900  157         0  southwest      smoker   16884.92400
# 1      20      F  36.770  160         1  southeast  non-smoker    1725.55230
# 2      33      F  35.000  145         3  southeast  non-smoker    4449.46200
# 3      37      F  23.705  153         0  northwest  non-smoker   21984.47061
# 4      36      F  27.880  156         0  northwest  non-smoker    3866.85520
# ...   ...    ...     ...  ...       ...        ...         ...           ...
# 1295   54      F  30.970  143         3  southwest  non-smoker   10600.54830
# 1296   22      M  34.920  156         0  northeast  non-smoker    2205.98080
# 1297   21      M  34.850  145         0  southeast  non-smoker    1629.83350
# 1298   22      M  24.800  150         0  northwest  non-smoker    2007.94500
# 1299   63      M  33.070  159         0  northwest      smoker   29141.36030
#
#       smoker_label
# 0                1
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 1295             0
# 1296             0
# 1297             0
# 1298             0
# 1299             1
#
# [1300 rows x 9 columns]

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>15. Create a variable which will contain the frequency of an individual's gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
list1=health['gender'].value_counts().to_dict()
health['gender_freq']=health['gender'].map(list1)
health
# Out:
#       age gender     bmi  bp   children     region      smoker  medical_cost  \
# 0      23      M  31.900  157         0  southwest      smoker   16884.92400
# 1      20      F  36.770  160         1  southeast  non-smoker    1725.55230
# 2      33      F  35.000  145         3  southeast  non-smoker    4449.46200
# 3      37      F  23.705  153         0  northwest  non-smoker   21984.47061
# 4      36      F  27.880  156         0  northwest  non-smoker    3866.85520
# ...   ...    ...     ...  ...       ...        ...         ...           ...
# 1295   54      F  30.970  143         3  southwest  non-smoker   10600.54830
# 1296   22      M  34.920  156         0  northeast  non-smoker    2205.98080
# 1297   21      M  34.850  145         0  southeast  non-smoker    1629.83350
# 1298   22      M  24.800  150         0  northwest  non-smoker    2007.94500
# 1299   63      M  33.070  159         0  northwest      smoker   29141.36030
#
#       smoker_label  gender_freq
# 0                1          643
# 1                0          657
# 2                0          657
# 3                0          657
# 4                0          657
# ...            ...          ...
# 1295             0          657
# 1296             0          643
# 1297             0          643
# 1298             0          643
# 1299             1          643
#
# [1300 rows x 10 columns]

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>16. Create a variable such that the value '1' indicates that the individual is a smoker and '0' indicates a non-smoker</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
def labeler(x):
    if x=='smoker':
        return 1
    else:
        return 0
health['smoker_label']=health['smoker'].apply(labeler)
health
# Out:
#       age gender     bmi  bp   children     region      smoker  medical_cost  \
# 0      23      M  31.900  157         0  southwest      smoker   16884.92400
# 1      20      F  36.770  160         1  southeast  non-smoker    1725.55230
# 2      33      F  35.000  145         3  southeast  non-smoker    4449.46200
# 3      37      F  23.705  153         0  northwest  non-smoker   21984.47061
# 4      36      F  27.880  156         0  northwest  non-smoker    3866.85520
# ...   ...    ...     ...  ...       ...        ...         ...           ...
# 1295   54      F  30.970  143         3  southwest  non-smoker   10600.54830
# 1296   22      M  34.920  156         0  northeast  non-smoker    2205.98080
# 1297   21      M  34.850  145         0  southeast  non-smoker    1629.83350
# 1298   22      M  24.800  150         0  northwest  non-smoker    2007.94500
# 1299   63      M  33.070  159         0  northwest      smoker   29141.36030
#
#       smoker_label  gender_freq
# 0                1          643
# 1                0          657
# 2                0          657
# 3                0          657
# 4                0          657
# ...            ...          ...
# 1295             0          657
# 1296             0          643
# 1297             0          643
# 1298             0          643
# 1299             1          643
#
# [1300 rows x 10 columns]

# %% [markdown]
# <a id="norm"> </a>
# ## 4. Normalization

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>17. Transform BMI such that it will have mean zero and variance one</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
i=health.select_dtypes(include=np.number).columns

health['scaled_bmi']=sc.fit_transform(pd.DataFrame(health['bmi']))
health
# Out:
#       age gender     bmi  bp   children     region      smoker  medical_cost  \
# 0      23      M  31.900  157         0  southwest      smoker   16884.92400
# 1      20      F  36.770  160         1  southeast  non-smoker    1725.55230
# 2      33      F  35.000  145         3  southeast  non-smoker    4449.46200
# 3      37      F  23.705  153         0  northwest  non-smoker   21984.47061
# 4      36      F  27.880  156         0  northwest  non-smoker    3866.85520
# ...   ...    ...     ...  ...       ...        ...         ...           ...
# 1295   54      F  30.970  143         3  southwest  non-smoker   10600.54830
# 1296   22      M  34.920  156         0  northeast  non-smoker    2205.98080
# 1297   21      M  34.850  145         0  southeast  non-smoker    1629.83350
# 1298   22      M  24.800  150         0  northwest  non-smoker    2007.94500
# 1299   63      M  33.070  159         0  northwest      smoker   29141.36030
#
#       scaled_bmi
# 0       0.050142
# 1       0.816583
# 2       0.538020
# 3      -1.239588
# 4      -0.582526
# ...          ...
# 1295   -0.096222
# 1296    0.525430
# 1297    0.514413
# 1298   -1.067257
# 1299    0.234277
#
# [1300 rows x 9 columns]

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>18. Check the range of 'age' and transform the values such that the range will be 1</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
health['scaled_age']=mm.fit_transform(pd.DataFrame(health['age']))
health
# Out:
#       age gender     bmi  bp   children     region      smoker  medical_cost  \
# 0      23      M  31.900  157         0  southwest      smoker   16884.92400
# 1      20      F  36.770  160         1  southeast  non-smoker    1725.55230
# 2      33      F  35.000  145         3  southeast  non-smoker    4449.46200
# 3      37      F  23.705  153         0  northwest  non-smoker   21984.47061
# 4      36      F  27.880  156         0  northwest  non-smoker    3866.85520
# ...   ...    ...     ...  ...       ...        ...         ...           ...
# 1295   54      F  30.970  143         3  southwest  non-smoker   10600.54830
# 1296   22      M  34.920  156         0  northeast  non-smoker    2205.98080
# 1297   21      M  34.850  145         0  southeast  non-smoker    1629.83350
# 1298   22      M  24.800  150         0  northwest  non-smoker    2007.94500
# 1299   63      M  33.070  159         0  northwest      smoker   29141.36030
#
#       scaled_bmi  scaled_age
# 0       0.050142        0.08
# 1       0.816583        0.02
# 2       0.538020        0.28
# 3      -1.239588        0.36
# 4      -0.582526        0.34
# ...          ...         ...
# 1295   -0.096222        0.70
# 1296    0.525430        0.06
# 1297    0.514413        0.04
# 1298   -1.067257        0.06
# 1299    0.234277        0.88
#
# [1300 rows x 10 columns]

# %% [markdown]
# <a id="trans"> </a>
# ## 5. Transformation Techniques

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>19. Check the skewness for 'medical_cost'. If the data is skewed, then use the appropriate technique to reduce the skewness in the data
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
x=np.log(health['medical_cost'])
y=health['medical_cost']
sns.distplot(x)
plt.show()
sns.distplot(y)
# Out:
# C:\Users\acer\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\acer\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='medical_cost', ylabel='Density'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>20. Transform the 'log_medical_cost' values to the original scale and compare the 'medical_cost' and the transformed data</b>
#                 </font>
#             </div>
#
# </td>
#     </tr>
# </table>

# %%
# import your code here
log=np.log(health.medical_cost)
antilog=np.exp(log)

plt.subplot(1,2,1)
sns.distplot(log)
plt.subplot(1,2,2)
sns.distplot(antilog)
# Out:
# C:\Users\acer\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\acer\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='medical_cost', ylabel='Density'>
